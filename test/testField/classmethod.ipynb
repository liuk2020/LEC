# %%
from lec.geometry import Surface

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Read from VMEC input

# %%
surfVMECinput_DIIID = Surface.readVMECInput("input.DIII-D")
surfVMECinput_heliotron = Surface.readVMECInput("input.heliotron")
surfVMECinput_QAS = Surface.readVMECInput("input.QAS")

# %%
_thetaArr = np.linspace(0, 2*np.pi, 100)
_zetaArr = np.linspace(0, 2*np.pi, 200)
thetaArr, zetaArr = np.meshgrid(_thetaArr, _zetaArr)
rArr = surfVMECinput_DIIID.r.getValue(thetaArr, zetaArr)
xArr = rArr * np.cos(zetaArr)
yArr = rArr * np.sin(zetaArr)
zArr = surfVMECinput_DIIID.z.getValue(thetaArr, zetaArr)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(xArr, yArr, zArr, color="violet")
plt.axis("equal")
# Out:
# (-2.4910891459235858,
#  2.4913713669009887,
#  -2.4912302564122872,
#  2.4912302564122872,
#  -1.868422692309215,
#  1.8684226923092155)

# %%
_thetaArr = np.linspace(0, 2*np.pi, 100)
_zetaArr = np.linspace(0, 2*np.pi, 200)
thetaArr, zetaArr = np.meshgrid(_thetaArr, _zetaArr)
rArr = surfVMECinput_heliotron.r.getValue(thetaArr, zetaArr)
xArr = rArr * np.cos(zetaArr)
yArr = rArr * np.sin(zetaArr)
zArr = surfVMECinput_heliotron.z.getValue(thetaArr, zetaArr)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(xArr, yArr, zArr, color="violet")
plt.axis("equal")
# Out:
# (-12.324135082289885,
#  12.460587350289533,
#  -12.392361216289709,
#  12.392361216289709,
#  -9.294270912217282,
#  9.294270912217282)

# %%
_thetaArr = np.linspace(0, 2*np.pi, 100)
_zetaArr = np.linspace(0, 2*np.pi, 200)
thetaArr, zetaArr = np.meshgrid(_thetaArr, _zetaArr)
rArr = surfVMECinput_QAS.r.getValue(thetaArr, zetaArr)
xArr = rArr * np.cos(zetaArr)
yArr = rArr * np.sin(zetaArr)
zArr = surfVMECinput_QAS.z.getValue(thetaArr, zetaArr)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(xArr, yArr, zArr, color="violet")
plt.axis("equal")
# Out:
# (-1.956651349881807,
#  1.932790181889155,
#  -1.944720765885481,
#  1.944720765885481,
#  -1.458540574414111,
#  1.458540574414111)

# %% [markdown]
# ## Read from VMEC output

# %%
surfVMECoutput_DIIID = Surface.readVMECOutput("wout_DIII-D.nc")
surfVMECoutput_heliotron = Surface.readVMECOutput("wout_heliotron.nc")
surfVMECoutput_QAS = Surface.readVMECOutput("wout_QAS.nc")

# %%
_thetaArr = np.linspace(0, 2*np.pi, 100)
_zetaArr = np.linspace(0, 2*np.pi, 200)
thetaArr, zetaArr = np.meshgrid(_thetaArr, _zetaArr)
rArr = surfVMECoutput_DIIID.r.getValue(thetaArr, zetaArr)
xArr = rArr * np.cos(zetaArr)
yArr = rArr * np.sin(zetaArr)
zArr = surfVMECoutput_DIIID.z.getValue(thetaArr, zetaArr)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(xArr, yArr, zArr, color="violet")
plt.axis("equal")
# Out:
# (-2.4924838091694435,
#  2.492766188151319,
#  -2.4926249986603812,
#  2.4926249986603812,
#  -1.869468748995286,
#  1.869468748995286)

# %%
_thetaArr = np.linspace(0, 2*np.pi, 100)
_zetaArr = np.linspace(0, 2*np.pi, 200)
thetaArr, zetaArr = np.meshgrid(_thetaArr, _zetaArr)
rArr = surfVMECoutput_heliotron.r.getValue(thetaArr, zetaArr)
xArr = rArr * np.cos(zetaArr)
yArr = rArr * np.sin(zetaArr)
zArr = surfVMECoutput_heliotron.z.getValue(thetaArr, zetaArr)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(xArr, yArr, zArr, color="violet")
plt.axis("equal")
# Out:
# (-12.324135082289885,
#  12.460587350289533,
#  -12.392361216289709,
#  12.392361216289709,
#  -9.294270912217282,
#  9.294270912217282)

# %%
_thetaArr = np.linspace(0, 2*np.pi, 100)
_zetaArr = np.linspace(0, 2*np.pi, 200)
thetaArr, zetaArr = np.meshgrid(_thetaArr, _zetaArr)
rArr = surfVMECoutput_QAS.r.getValue(thetaArr, zetaArr)
xArr = rArr * np.cos(zetaArr)
yArr = rArr * np.sin(zetaArr)
zArr = surfVMECoutput_QAS.z.getValue(thetaArr, zetaArr)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(xArr, yArr, zArr, color="violet")
plt.axis("equal")
# Out:
# (-1.9565779257617955,
#  1.9327139656949326,
#  -1.9446459457283638,
#  1.9446459457283642,
#  -1.4584844592962731,
#  1.4584844592962731)
