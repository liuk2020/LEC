# %%
import lec
import xarray
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


vmecOutput = "./../testField/wout_heliotron.nc" 
surf = lec.Surface.readVMECOutput(vmecOutput)
iota = float(xarray.open_dataset(vmecOutput)["iotas"].values[-1])

# %%
eqHeliotron= lec.SurfaceEquilibrium(surf=surf, iota=iota)

# %%
_thetaArr = np.linspace(0, 2*np.pi, 100)
_zetaArr = np.linspace(0, 2*np.pi, 200)
thetaArr, zetaArr = np.meshgrid(_thetaArr, _zetaArr)
rArr = eqHeliotron.surf.r.getValue(thetaArr, zetaArr)
xArr = rArr * np.cos(zetaArr)
yArr = rArr * np.sin(zetaArr)
zArr = eqHeliotron.surf.z.getValue(thetaArr, zetaArr)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(xArr, yArr, zArr, color="violet")
_ = plt.axis("equal")

# %%
eqHeliotron.run()

# %%
import matplotlib
matplotlib.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
eqHeliotron.Jacobian.plot_plt(ax=ax, fig=fig)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4.3))
lec.toroidalField.derivatePol(eqHeliotron.P*eqHeliotron.Jacobian).plot_plt(fig=fig, ax=ax[0])
lec.toroidalField.derivateTor(eqHeliotron.Q*eqHeliotron.Jacobian).plot_plt(fig=fig, ax=ax[1])
